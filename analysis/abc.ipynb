# %%
PATH = "C:/Users/fguid/Downloads/HMEC_top_hub_GO_enrich_results.tsv"

# %%
import pandas as pd

data = pd.read_csv(PATH, sep="\t")

# sort by FDR
data = data.sort_values(by="FDR")
data
# Out:
#                                              Gene.Set       FDR        OR  \
# 2   GOBP_DNA_REPLICATION_DEPENDENT_CHROMATIN_ORGAN...  0.000531  1.865383
# 4   GOBP_EXTERNAL_ENCAPSULATING_STRUCTURE_ORGANIZA...  0.000531  1.337784
# 15                            GOBP_TISSUE_DEVELOPMENT  0.002003  1.120804
# 8                            GOBP_RESPONSE_TO_HORMONE  0.002666  1.184218
# 12                           GOBP_BIOLOGICAL_ADHESION  0.003163  1.135390
# 6                           GOBP_RESPONSE_TO_WOUNDING  0.003163  1.214935
# 17       GOBP_PROTEIN_CONTAINING_COMPLEX_ORGANIZATION  0.003163  1.112883
# 13               GOBP_RESPONSE_TO_ENDOGENOUS_STIMULUS  0.003947  1.125911
# 10                            GOBP_TUBE_MORPHOGENESIS  0.005644  1.160447
# 16        GOBP_RESPONSE_TO_OXYGEN_CONTAINING_COMPOUND  0.005770  1.119548
# 11                              GOBP_TUBE_DEVELOPMENT  0.005770  1.142694
# 3                     GOBP_COLLAGEN_METABOLIC_PROCESS  0.005770  1.492307
# ...
